# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

# %%
import os
import json
import requests

BASE_URL = os.environ.get('OLLAMA_HOST', 'http://localhost:11434')

# Generate a response for a given prompt with a provided model. This is a streaming endpoint, so will be a series of responses.
# The final response object will include statistics and additional data from the request. Use the callback function to override
# the default handler.
def generate(model_name, prompt, system=None, template=None, context=None, options=None, callback=None):
    try:
        url = f"{BASE_URL}/api/generate"
        payload = {
            "model": model_name, 
            "prompt": prompt, 
            "system": system, 
            "template": template, 
            "context": context, 
            "options": options
        }
        
        # Remove keys with None values
        payload = {k: v for k, v in payload.items() if v is not None}
        
        with requests.post(url, json=payload, stream=True) as response:
            response.raise_for_status()
            
            # Creating a variable to hold the context history of the final chunk
            final_context = None
            
            # Variable to hold concatenated response strings if no callback is provided
            full_response = ""

            # Iterating over the response line by line and displaying the details
            for line in response.iter_lines():
                if line:
                    # Parsing each line (JSON chunk) and extracting the details
                    chunk = json.loads(line)
                    
                    # If a callback function is provided, call it with the chunk
                    if callback:
                        callback(chunk)
                    else:
                        # If this is not the last chunk, add the "response" field value to full_response and print it
                        if not chunk.get("done"):
                            response_piece = chunk.get("response", "")
                            full_response += response_piece
                            print(response_piece, end="", flush=True)
                    
                    # Check if it's the last chunk (done is true)
                    if chunk.get("done"):
                        final_context = chunk.get("context")
            
            # Return the full response and the final context
            return full_response, final_context
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None, None

# Create a model from a Modelfile. Use the callback function to override the default handler.
def create(model_name, model_path, callback=None):
    try:
        url = f"{BASE_URL}/api/create"
        payload = {"name": model_name, "path": model_path}
        
        # Making a POST request with the stream parameter set to True to handle streaming responses
        with requests.post(url, json=payload, stream=True) as response:
            response.raise_for_status()

            # Iterating over the response line by line and displaying the status
            for line in response.iter_lines():
                if line:
                    # Parsing each line (JSON chunk) and extracting the status
                    chunk = json.loads(line)

                    if callback:
                        callback(chunk)
                    else:
                        print(f"Status: {chunk.get('status')}")
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")

# Pull a model from a the model registry. Cancelled pulls are resumed from where they left off, and multiple
# calls to will share the same download progress. Use the callback function to override the default handler.
def pull(model_name, insecure=False, callback=None):
    try:
        url = f"{BASE_URL}/api/pull"
        payload = {
            "name": model_name,
            "insecure": insecure
        }

        # Making a POST request with the stream parameter set to True to handle streaming responses
        with requests.post(url, json=payload, stream=True) as response:
            response.raise_for_status()

            # Iterating over the response line by line and displaying the details
            for line in response.iter_lines():
                if line:
                    # Parsing each line (JSON chunk) and extracting the details
                    chunk = json.loads(line)

                    # If a callback function is provided, call it with the chunk
                    if callback:
                        callback(chunk)
                    else:
                        # Print the status message directly to the console
                        print(chunk.get('status', ''), end='', flush=True)
                    
                    # If there's layer data, you might also want to print that (adjust as necessary)
                    if 'digest' in chunk:
                        print(f" - Digest: {chunk['digest']}", end='', flush=True)
                        print(f" - Total: {chunk['total']}", end='', flush=True)
                        print(f" - Completed: {chunk['completed']}", end='\n', flush=True)
                    else:
                        print()
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")

# Push a model to the model registry. Use the callback function to override the default handler.
def push(model_name, insecure=False, callback=None):
    try:
        url = f"{BASE_URL}/api/push"
        payload = {
            "name": model_name,
            "insecure": insecure
        }

        # Making a POST request with the stream parameter set to True to handle streaming responses
        with requests.post(url, json=payload, stream=True) as response:
            response.raise_for_status()

            # Iterating over the response line by line and displaying the details
            for line in response.iter_lines():
                if line:
                    # Parsing each line (JSON chunk) and extracting the details
                    chunk = json.loads(line)

                    # If a callback function is provided, call it with the chunk
                    if callback:
                        callback(chunk)
                    else:
                        # Print the status message directly to the console
                        print(chunk.get('status', ''), end='', flush=True)
                    
                    # If there's layer data, you might also want to print that (adjust as necessary)
                    if 'digest' in chunk:
                        print(f" - Digest: {chunk['digest']}", end='', flush=True)
                        print(f" - Total: {chunk['total']}", end='', flush=True)
                        print(f" - Completed: {chunk['completed']}", end='\n', flush=True)
                    else:
                        print()
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")

# List models that are available locally.
def list():
    try:
        response = requests.get(f"{BASE_URL}/api/tags")
        response.raise_for_status()
        data = response.json()
        models = data.get('models', [])
        return models

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# Copy a model. Creates a model with another name from an existing model.
def copy(source, destination):
    try:
        # Create the JSON payload
        payload = {
            "source": source,
            "destination": destination
        }
        
        response = requests.post(f"{BASE_URL}/api/copy", json=payload)
        response.raise_for_status()
        
        # If the request was successful, return a message indicating that the copy was successful
        return "Copy successful"

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# Delete a model and its data.
def delete(model_name):
    try:
        url = f"{BASE_URL}/api/delete"
        payload = {"name": model_name}
        response = requests.delete(url, json=payload)
        response.raise_for_status()
        return "Delete successful"
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# Show info about a model.
def show(model_name):
    try:
        url = f"{BASE_URL}/api/show"
        payload = {"name": model_name}
        response = requests.post(url, json=payload)
        response.raise_for_status()
        
        # Parse the JSON response and return it
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

def heartbeat():
    try:
        url = f"{BASE_URL}/"
        response = requests.head(url)
        response.raise_for_status()
        return "Ollama is running"
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return "Ollama is not running"

# %%
import uuid
import pandas as pd
import numpy as np
import sys

import json
# import ollama.client as client


def extractConcepts(prompt: str, metadata={}, model="mistral-openorca:latest"):
    SYS_PROMPT = (
        "Your task is extract the key concepts (and non personal entities) mentioned in the given context. "
        "Extract only the most important and atomistic concepts, if  needed break the concepts down to the simpler concepts."
        "Categorize the concepts in one of the following categories: "
        "[event, concept, place, object, document, organisation, condition, misc]\n"
        "Format your output as a list of json with the following format:\n"
        "[\n"
        "   {\n"
        '       "entity": The Concept,\n'
        '       "importance": The concontextual importance of the concept on a scale of 1 to 5 (5 being the highest),\n'
        '       "category": The Type of Concept,\n'
        "   }, \n"
        "{ }, \n"
        "]\n"
    )
    response, _ = generate(model_name=model, system=SYS_PROMPT, prompt=prompt)
    try:
        result = json.loads(response)
        result = [dict(item, **metadata) for item in result]
    except:
        print("\n\nERROR ### Here is the buggy response: ", response, "\n\n")
        result = None
    return result


def graphPrompt(input: str, metadata={}, model="mistral-openorca:latest"):
    if model == None:
        model = "mistral-openorca:latest"

    # model_info = client.show(model_name=model)
    # print( chalk.blue(model_info))

    SYS_PROMPT = (
        "You are a network graph maker who extracts terms and their relations from a given context. "
        "You are provided with a context chunk (delimited by ```) Your task is to extract the ontology "
        "of terms mentioned in the given context. These terms should represent the key concepts as per the context. \n"
        "Thought 1: While traversing through each sentence, Think about the key terms mentioned in it.\n"
            "\tTerms may include object, entity, location, organization, person, \n"
            "\tcondition, acronym, documents, service, concept, etc.\n"
            "\tTerms should be as atomistic as possible\n\n"
        "Thought 2: Think about how these terms can have one on one relation with other terms.\n"
            "\tTerms that are mentioned in the same sentence or the same paragraph are typically related to each other.\n"
            "\tTerms can be related to many other terms\n\n"
        "Thought 3: Find out the relation between each such related pair of terms. \n\n"
        "Format your output as a list of json. Each element of the list contains a pair of terms"
        "and the relation between them, like the follwing: \n"
        "[\n"
        "   {\n"
        '       "node_1": "A concept from extracted ontology",\n'
        '       "node_2": "A related concept from extracted ontology",\n'
        '       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n'
        "   }, {...}\n"
        "]"
    )

    USER_PROMPT = f"context: ```{input}``` \n\n output: "
    response, _ = generate(model_name=model, system=SYS_PROMPT, prompt=USER_PROMPT)
    try:
        result = json.loads(response)
        result = [dict(item, **metadata) for item in result]
    except:
        print("\n\nERROR ### Here is the buggy response: ", response, "\n\n")
        result = None
    return result


def documents2Dataframe(documents) -> pd.DataFrame:
    rows = []
    for chunk in documents:
        row = {
            "text": chunk.page_content,
            **chunk.metadata,
            "chunk_id": uuid.uuid4().hex,
        }
        rows = rows + [row]

    df = pd.DataFrame(rows)
    return df


def df2ConceptsList(dataframe: pd.DataFrame) -> list:
    # dataframe.reset_index(inplace=True)
    results = dataframe.apply(
        lambda row: extractConcepts(
            row.text, {"chunk_id": row.chunk_id, "type": "concept"}
        ),
        axis=1,
    )
    # invalid json results in NaN
    results = results.dropna()
    results = results.reset_index(drop=True)

    ## Flatten the list of lists to one single list of entities.
    concept_list = np.concatenate(results).ravel().tolist()
    return concept_list


def concepts2Df(concepts_list) -> pd.DataFrame:
    ## Remove all NaN entities
    concepts_dataframe = pd.DataFrame(concepts_list).replace(" ", np.nan)
    concepts_dataframe = concepts_dataframe.dropna(subset=["entity"])
    concepts_dataframe["entity"] = concepts_dataframe["entity"].apply(
        lambda x: x.lower()
    )

    return concepts_dataframe


def df2Graph(dataframe: pd.DataFrame, model=None) -> list:
    # dataframe.reset_index(inplace=True)
    results = dataframe.apply(
        lambda row: graphPrompt(row.text, {"chunk_id": row.chunk_id}, model), axis=1
    )
    # invalid json results in NaN
    results = results.dropna()
    results = results.reset_index(drop=True)

    ## Flatten the list of lists to one single list of entities.
    concept_list = np.concatenate(results).ravel().tolist()
    return concept_list


def graph2Df(nodes_list) -> pd.DataFrame:
    ## Remove all NaN entities
    graph_dataframe = pd.DataFrame(nodes_list).replace(" ", np.nan)
    graph_dataframe = graph_dataframe.dropna(subset=["node_1", "node_2"])
    graph_dataframe["node_1"] = graph_dataframe["node_1"].apply(lambda x: x.lower())
    graph_dataframe["node_2"] = graph_dataframe["node_2"].apply(lambda x: x.lower())

    return graph_dataframe

# %% [markdown]
# ## Load Documents

# %%
loader = DirectoryLoader('random_mrns/deid/', show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
# 100%|██████████| 8/8 [00:13<00:00,  1.73s/it]
# Number of chunks =  4738
# Subjective:       Patient ID: Jerry Adams is a 69 y.o. male. HPI  Patient is here for follow-up on chronic medical problems  He has prostate cancer he started radiation therapy this week, he reports that he is feeling down and he has been eating more for comfort. He also reports that he has good supportive system and he is trying to walk on daily basis. He has hypertension he is compliant with his medications he denies chest pain shortness of breath  He has hyperlipidemia tolerating statin    The following portions of the patient's history were reviewed and updated as appropriate: allergies, current medications, past family history, past medical history, past social history, past surgical history and problem list. Review of Systems   Constitutional: Negative. HENT: Negative for rhinorrhea, sinus pain and sore throat. Eyes: Negative. Respiratory: Negative. Cardiovascular: Negative. Gastrointestinal: Negative. Genitourinary: Negative. Musculoskeletal: Negative. Neurological: Negative. Psychiatric/Behavioral: Negative. Objective:    Blood pressure 118/78, pulse 82, temperature 36.7 °C (98 °F), weight 113.4 kg (250 lb), SpO2 100 %. Physical Exam  Vitals and nursing note reviewed. Constitutional:       General: He is not in acute distress. Appearance: Normal appearance. He is well-developed. HENT:      Head: Normocephalic and atraumatic. Mouth/Throat:      Pharynx: No oropharyngeal exudate. Eyes:      Conjunctiva/sclera: Conjunctivae normal.

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (4738, 3)
#                                                 text  \
# 0  Subjective:       Patient ID: Jerry Adams is a...
# 1  Pupils: Pupils are equal, round, and reactive ...
# 2  Diagnoses and all orders for this visit:    Es...
# 3  Subjective:       Patient ID: Jerry Adams is a...
# 4  Pupils: Pupils are equal, round, and reactive ...
#
#                             source                          chunk_id
# 0  random_mrns/deid/19064752_3.txt  38d3e5b0b5854945bd1ac139e7717c04
# 1  random_mrns/deid/19064752_3.txt  b739c01a3f914a1c836f8890d6b913cb
# 2  random_mrns/deid/19064752_3.txt  17668bec3a87441ca65973b17eb1f444
# 3  random_mrns/deid/19064752_3.txt  87e240c8608e4d428d064fb83e514772
# 4  random_mrns/deid/19064752_3.txt  5eafdb7d105d4f9b903cb3fca7be9761

# %%
#select only the first 10 chunks
df = df.iloc[:10]
df.shape
# Out:
# (10, 3)

# %%
print("Word Count Statistics")
print(df.text.str.split().str.len().describe())
# Out:
# Word Count Statistics
# count    4738.000000
# mean      184.679823
# std        42.298449
# min         6.000000
# 25%       154.250000
# 50%       194.000000
# 75%       217.000000
# max       251.000000
# Name: text, dtype: float64

# %% [markdown]
# ## Extract Concepts

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
outputdirectory = 'graphs/'
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory + "graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory + "chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# [
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "Patient ID: ",
#     "edge": "Jerry Adams is the patient being discussed and reviewed in this context."
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "69 y.o.",
#     "edge": "Jerry Adams is a 69 year old male, as stated in the context."
#   },
#   {
#     "node_1": "prostate cancer",
#     "node_2": "started radiation therapy this week",
#     "edge": "The patient has been diagnosed with prostate cancer and recently began radiation therapy for it, as mentioned in the context."
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "compliant with his medications",
#     "edge": "According to the context, Jerry Adams is adhering to his medication regimen for his underlying medical conditions."
#   },
#   {
#     "node_1": "chest pain",
#     "node_2": "shortness of breath",
#     "edge": "The patient denies experiencing symptoms of chest pain and shortness of breath, as noted in the context."
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "good supportive system",
#     "edge": "The patient has a supportive social network, as indicated in the context."
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "trying to walk on daily basis",
#     "edge": "As per the context, Jerry Adams is making an effort to engage in regular walking as part of his routine."
#   },
#   {
#     "node_1": "hypertension",
#     "node_2": "compliant with medications",
#     "edge": "The patient is following the recommended medical treatment for hypertension, as mentioned in the context."
#   },
#   {
#     "node_1": "hyperlipidemia",
#     "node_2": "tolerating statin",
#     "edge": "According to the context, Jerry Adams has hyperlipidemia and is managing it by taking statins."
#   },
#   {
#     "node_1": "allergies",
#     "node_2": "reviewed and updated as appropriate",
#     "edge": "As noted in the context, any known allergies of the patient have been reviewed and modified if required."
#   },
#   {
#     "node_1": "current medications",
#     "node_2": "reviewed and updated as appropriate",
#     "edge": "The current medication regimen of the patient has been assessed and adjusted, if necessary, as indicated in the context."
#   },
#   {
#     "node_1": "past family history",
#     "node_2": "reviewed and updated as appropriate",
#     "edge": "According to the context, any relevant past family medical histories have been reviewed and altered if needed."
#   },
#   {
#     "node_1": "past medical history",
#     "node_2": "reviewed and updated as appropriate",
#     "edge": "As mentioned in the context, any previously documented medical issues of the patient have been reviewed and revised if required."
#   },
#   {
#     "node_1": "past social history",
#     "node_2": "reviewed and updated as appropriate",
#     "edge": "The past social background of the patient has been re-examined and modified, if necessary, as mentioned in the context."
#   },
#   {
#     "node_1": "past surgical history",
#     "node_2": "reviewed and updated as appropriate",
#     "edge": "The context indicates that any significant prior surgeries of the patient have been reviewed and amended if needed."
#   }
# ][
#   {
#     "node_1": "Pupils",
#     "node_2": "Eyes",
#     "edge": "Pupils are part of the eyes and can reveal important information about a person's health, such as their eye condition or reaction to light."
#   },
#   {
#     "node_1": "Neck",
#     "node_2": "Thyroid",
#     "edge": "The thyroid gland is located in the neck and can be examined for signs of thyromegaly (enlargement)."
#   },
#   {
#     "node_1": "Rate",
#     "node_2": "Heart Rate",
#     "edge": "Heart rate refers to the number of times the heart beats in a minute and is an important vital sign."
#   },
#   {
#     "node_1": "Rhythm",
#     "node_2": "Heart Rhythm",
#     "edge": "Heart rhythm describes the regularity or irregularity of heartbeats and can provide insight into a person's overall cardiovascular health."
#   },
#   {
#     "node_1": "Effort",
#     "node_2": "Pulmonary Effort",
#     "edge": "Pulmonary effort refers to the amount of energy required to breathe and can be used to assess respiratory function in patients."
#   },
#   {
#     "node_1": "Breath Sounds",
#     "node_2": "Lungs",
#     "edge": "Breath sounds are produced by air moving in and out of the lungs, and can help to identify potential respiratory issues."
#   },
#   {
#     "node_1": "Abdominal",
#     "node_2": "Abdomen",
#     "edge": "The abdomen contains many internal organs, such as the liver, stomach, and intestines, and can be examined for signs of tenderness or mass."
#   },
#   {
#     "node_1": "Range of Motion",
#     "node_2": "Cervical Back",
#     "edge": "The cervical spine is located in the neck region and can be assessed for range of motion, which can provide insight into potential musculoskeletal issues."
#   },
#   {
#     "node_1": "Lymphadenopathy",
#     "node_2": "Cervical",
#     "edge": "Cervical lymph nodes are located in the neck region and can be examined for signs of enlargement, which may indicate potential infection or disease."
#   },
#   {
#     "node_1": "Capillary Refill",
#     "node_2": "Skin",
#     "edge": "Capillary refill refers to the time it takes for blood to return to a pressed area of skin and can provide insight into overall circulation."
#   },
#   {
#     "node_1": "Focal Deficit",
#     "node_2": "Neurological",
#     "edge": "A focal deficit refers to a specific neurological impairment, such as paralysis or weakness in a particular area of the body."
#   },
#   {
#     "node_1": "Mental Status",
#     "node_2": "Neurological",
#     "edge": "A person's mental status provides insight into their cognitive function, such as memory, attention, and orientation to time, place, and person."
#   },
#   {
#     "node_1": "Psychiatric",
#     "node_2": "Thought Content",
#     "edge": "Thought content refers to a person's internal mental experiences, such as their beliefs, perceptions, or worries."
#   },
#   {
#     "node_1": "Psychiatric",
#     "node_2": "Judgment",
#     "edge": "Judgment refers to a person's ability to make sound decisions and understand the potential consequences of their actions."
#   },
#   {
#     "node_1": "Return Visit",
#     "node_2": "Patient Care",
#     "edge": "A return visit refers to a follow-up appointment with a healthcare provider, which may provide additional insight into a person's overall health status."
#   }
# ][
#   {
#     "node_1": "Malignant neoplasm of prostate (CMS-hcc)",
#     "node_2": "Patient following with urologist",
#     "edge": "The patient is undergoing follow-up care for their prostate cancer at the recommendation of their urologist."
#   },
#   {
#     "node_1": "Colon cancer screening",
#     "node_2": "Cologuard (EXACT SCIENCES)",
#     "edge": "The patient is undergoing colon cancer screening through the use of the Cologuard test from EXACT SCIENCES."
#   },
#   {
#     "node_1": "Class 3 severe obesity due to excess calories with serious comorbidity and body mass index (BMI) of 40.0 to 44.9 in adult (CMS-hcc)",
#     "node_2": "Patient",
#     "edge": "The patient is currently experiencing severe obesity due to excessive calorie intake, which has resulted in serious comorbidities and a body mass index (BMI) falling between 40.0 and 44.9 as classified by the Centers for Medicare & Medicaid Services (CMS-hcc)."
#   },
#   {
#     "node_1": "Essential hypertension",
#     "node_2": "Blood pressure under control",
#     "edge": "The patient has been diagnosed with essential hypertension, and their blood pressure is currently being successfully managed."
#   },
#   {
#     "node_1": "Mixed hyperlipidemia",
#     "node_2": "Patient to continue simvastatin",
#     "edge": "The patient has been diagnosed with mixed hyperlipidemia and is currently prescribed simvastatin as a treatment."
#   }
# ][
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "patient",
#     "edge": "Jerry Adams is a 69 y.o. male who presents for follow-up on his chronic medical problems."
#   },
#   {
#     "node_1": "prostate cancer",
#     "node_2": "chronic medical problem",
#     "edge": "Jerry Adams has prostate cancer, which is a chronic medical problem that he is being followed up for."
#   },
#   {
#     "node_1": "radiation therapy",
#     "node_2": "prostate cancer",
#     "edge": "Jerry Adams recently started radiation therapy to manage his prostate cancer."
#   },
#   {
#     "node_1": "comfort eating",
#     "node_2": "eating more",
#     "edge": "As a result of feeling down, Jerry Adams has been consuming more food for comfort."
#   },
#   {
#     "node_1": "hypertension",
#     "node_2": "chronic medical problem",
#     "edge": "Jerry Adams also suffers from hypertension, which is another chronic medical condition he is managing."
#   },
#   {
#     "node_1": "statin",
#     "node_2": "hyperlipidemia",
#     "edge": "Jerry Adams tolerates statins as a means of managing his hyperlipidemia."
#   },
#   {
#     "node_1": "review and update",
#     "node_2": "allergies, current medications, past family history, past medical history, past social history, past surgical history, problem list",
#     "edge": "During Jerry Adams' visit, his healthcare provider reviewed and updated relevant information pertaining to his allergies, current medications, past family history, past medical history, past social history, past surgical history, and problem list."
#   },
#   {
#     "node_1": "negative",
#     "node_2": "rhinorrhea, sinus pain, sore throat",
#     "edge": "Jerry Adams reports that he is currently free from rhinorrhea, sinus pain, and sore throat."
#   },
#   {
#     "node_1": "negative",
#     "node_2": "constitutional",
#     "edge": "Overall, Jerry Adams appears to be in good health at the moment."
#   },
#   {
#     "node_1": "normal appearance",
#     "node_2": "appearance",
#     "edge": "Jerry Adams has a normal physical appearance."
#   },
#   {
#     "node_1": "atraumatic",
#     "node_2": "head",
#     "edge": "Jerry Adams' head is free from any traumatic injury or abnormality."
#   },
#   {
#     "node_1": "normal",
#     "node_2": "conjunctiva/sclera",
#     "edge": "Jerry Adams' conjunctiva and sclera are both normal in appearance."
#   }
# ][
#    {
#        "node_1": "Pupils",
#        "node_2": "Light",
#        "edge": "Pupils are equal, round, and reactive to light."
#    },
#    {
#        "node_1": "Neck",
#        "node_2": "Thyroid",
#        "edge": "No thyromegaly was found in the neck region related to thyroid."
#    },
#    {
#        "node_1": "Rate",
#        "node_2": "Rhythm",
#        "edge": "Normal rate and regular rhythm were observed."
#    },
#    {
#        "node_1": "Pulmonary",
#        "node_2": "Effort",
#        "edge": "The pulmonary effort was normal."
#    },
#    {
#        "node_1": "Breath sounds",
#        "node_2": "Normal breath sounds",
#        "edge": "Normal breath sounds were heard."
#    },
#    {
#        "node_1": "Cardiovascular",
#        "node_2": "Heart sounds",
#        "edge": "Normal heart sounds were present."
#    },
#    {
#        "node_1": "Abdominal",
#        "node_2": "Bowel sounds",
#        "edge": "The bowel sounds were normal."
#    },
#    {
#        "node_1": "Abdominal",
#        "node_2": "Distension",
#        "edge": "There was no distension in the abdominal region."
#    },
#    {
#        "node_1": "Musculoskeletal",
#        "node_2": "General",
#        "edge": "The patient had a normal range of motion in this area."
#    },
#    {
#        "node_1": "Cervical back",
#        "node_2": "Normal range of motion",
#        "edge": "The patient had a normal range of motion in this area."
#    },
#    {
#        "node_1": "Lymphadenopathy",
#        "node_2": "Cervical",
#        "edge": "No cervical adenopathy was found."
#    },
#    {
#        "node_1": "Skin",
#        "node_2": "General",
#        "edge": "The skin was warm."
#    },
#    {
#        "node_1": "Capillary Refill",
#        "node_2": "Normal range of time",
#        "edge": "The capillary refill took less than 2 seconds."
#    },
#    {
#        "node_1": "Neurological",
#        "node_2": "General",
#        "edge": "No focal deficits were found."
#    },
#    {
#        "node_1": "Mental Status",
#        "node_2": "Jerry",
#        "edge": "The patient was alert and oriented to person, place, and time."
#    }
# ][
#   {
#     "node_1": "Malignant neoplasm of prostate (CMS-hcc)",
#     "node_2": "Patient following with urologist",
#     "edge": "The patient is receiving follow-up care for their prostate cancer at a urology clinic."
#   },
#   {
#     "node_1": "Essential hypertension",
#     "node_2": "Blood pressure under control",
#     "edge": "The patient's essential hypertension is currently being managed and their blood pressure levels are within a healthy range."
#   },
#   {
#     "node_1": "Mixed hyperlipidemia",
#     "node_2": "Patient to continue simvastatin",
#     "edge": "The patient has mixed hyperlipidemia and their doctor has prescribed simvastatin as a treatment to manage the condition."
#   },
#   {
#     "node_1": "Class 3 severe obesity due to excess calories with serious comorbidity and body mass index (BMI) of 40.0 to 44.9 in adult (CMS-hcc)",
#     "node_2": "Patient",
#     "edge": "The patient is currently experiencing severe obesity as a result of consuming excess calories, which has led to serious comorbidities and a BMI within the CMS-hcc classification range."
#   },
#   {
#     "node_1": "Colon cancer screening",
#     "node_2": "Cologuard (EXACT SCIENCES)",
#     "edge": "The patient is undergoing colon cancer screening using the Cologuard test provided by Exact Sciences."
#   },
#   {
#     "node_1": "Immunization due",
#     "node_2": "Td (Adult) with Preservative",
#     "edge": "The patient is overdue for their adult tetanus, diphtheria, and pertussis (Td) vaccine, which should be administered without the use of preservatives."
#   }
# ][
#    {
#        "node_1": "Jerry Adams",
#        "node_2": "69 y.o.",
#        "edge": "Jerry Adams is a 69 year old male."
#    },
#    {
#        "node_1": "hypertension",
#        "node_2": "follow up",
#        "edge": "Patient ID: Jerry Adams is receiving follow-up care for hypertension."
#    },
#    {
#        "node_1": "hyperlipidemia",
#        "node_2": "controlled",
#        "edge": "Hyperlipidemia for patient ID: Jerry Adams is controlled."
#    },
#    {
#        "node_1": "prostate cancer",
#        "node_2": "recurrence",
#        "edge": "Patient ID: Jerry Adams has a recurrence of prostate cancer."
#    },
#    {
#        "node_1": "radiation",
#        "node_2": "is on radiation",
#        "edge": "Patient ID: Jerry Adams is currently undergoing radiation treatment for his prostate cancer."
#    },
#    {
#        "node_1": "obesity",
#        "node_2": "advised about diet",
#        "edge": "Patient ID: Jerry Adams has been advised on a diet to manage his obesity."
#    },
#    {
#        "node_1": "Jerry Adams",
#        "node_2": "light-headedness",
#        "edge": "Patient ID: Jerry Adams is presenting with light-headedness during this examination."
#    }
# ][
#   {
#     "node_1": "dizziness",
#     "node_2": "symptom",
#     "edge": "Jerry presented with symptoms of dizziness during his visit."
#   },
#   {
#     "node_1": "Jerry",
#     "node_2": "patient",
#     "edge": "During the appointment, Jerry was examined by the healthcare provider."
#   },
#   {
#     "node_1": "dizziness",
#     "node_2": "health concern",
#     "edge": "The healthcare provider assessed Jerry's health concern of dizziness."
#   },
#   {
#     "node_1": "symptom",
#     "node_2": "medical term",
#     "edge": "During the appointment, the healthcare provider discussed Jerry's symptoms with him."
#   },
#   {
#     "node_1": "patient",
#     "node_2": "individual seeking medical care",
#     "edge": "Jerry sought medical care during his appointment for dizziness."
#   },
#   {
#     "node_1": "health concern",
#     "node_2": "medical issue being addressed",
#     "edge": "The healthcare provider addressed Jerry's health concern of dizziness during the appointment."
#   },
#   {
#     "node_1": "Jerry",
#     "node_2": "individual with medical history",
#     "edge": "During the appointment, Jerry shared his medical history with the healthcare provider."
#   },
#   {
#     "node_1": "alert",
#     "node_2": "mental status",
#     "edge": "The healthcare provider noted that Jerry was alert during the appointment."
#   },
#   {
#     "node_1": "orientation",
#     "node_2": "mental status",
#     "edge": "Jerry was oriented to person, place, and time during the appointment."
#   },
#   {
#     "node_1": "time",
#     "node_2": "spatial or temporal concept",
#     "edge": "Jerry's orientation to time was assessed by the healthcare provider during the appointment."
#   }
# ][
#   {
#     "node_1": "Malignant neoplasm of prostate (CMS-hcc)",
#     "node_2": "Class 3 severe obesity due to excess calories with serious comorbidity and body mass index (BMI) of 40.0 to 44.9 in adult (CMS-hcc)",
#     "edge": "Co-occurrence in the context, as both conditions are listed under 'Diagnoses' for this visit."
#   },
#   {
#     "node_1": "Malignant neoplasm of prostate (CMS-hcc)",
#     "node_2": "Essential hypertension",
#     "edge": "Co-occurrence in the context, as both conditions are listed under 'Diagnoses' for this visit."
#   },
#   {
#     "node_1": "Mixed hyperlipidemia",
#     "node_2": "Class 3 severe obesity due to excess calories with serious comorbidity and body mass index (BMI) of 40.0 to 44.9 in adult (CMS-hcc)",
#     "edge": "Co-occurrence in the context, as both conditions are listed under 'Diagnoses' for this visit."
#   },
#   {
#     "node_1": "Mixed hyperlipidemia",
#     "node_2": "Essential hypertension",
#     "edge": "Co-occurrence in the context, as both conditions are listed under 'Diagnoses' for this visit."
#   },
#   {
#     "node_1": "Vertigo",
#     "node_2": "Meclizine (ANTIVERT)",
#     "edge": "Causation relationship, as meclizine is prescribed to manage symptoms of vertigo."
#   }
# ][
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "Patient ID: ",
#     "edge": "Relationship: Jerry Adams is associated with the patient identification number provided in this context."
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "is a",
#     "edge": "Relationship: Jerry Adams is classified as a person, as denoted by 'is a'"
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "69 y.o.",
#     "edge": "Relationship: Jerry Adams' age is provided in this context."
#   },
#   {
#     "node_1": "Patient ID:",
#     "node_2": "Jerry Adams",
#     "edge": "Relationship: Jerry Adams is associated with the patient identification number provided in this context."
#   },
#   {
#     "node_1": "Hypertension",
#     "node_2": "controlled",
#     "edge": "Relationship: Hypertension in Jerry Adams' case is classified as 'controlled'."
#   },
#   {
#     "node_1": "Hyperlipidemia",
#     "node_2": "controlled",
#     "edge": "Relationship: Hyperlipidemia in Jerry Adams' case is classified as 'controlled'."
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "has obesity",
#     "edge": "Relationship: Jerry Adams is associated with the medical condition of 'obesity'."
#   },
#   {
#     "node_1": "Prostate cancer",
#     "node_2": "recurrence",
#     "edge": "Relationship: Jerry Adams has experienced a recurrence of his prostate cancer."
#   },
#   {
#     "node_1": "Radiation",
#     "node_2": "is used for",
#     "edge": "Relationship: Radiation is being utilized to treat Jerry Adams' prostate cancer."
#   },
#   {
#     "node_1": "Jerry Adams",
#     "node_2": "has vertigo",
#     "edge": "Relationship: Jerry Adams has recently experienced symptoms of vertigo."
#   }
# ](100, 5)
#             node_1                               node_2  \
# 0      jerry adams                         patient id:
# 1      jerry adams                              69 y.o.
# 2  prostate cancer  started radiation therapy this week
# 3      jerry adams       compliant with his medications
# 4       chest pain                  shortness of breath
#
#                                                 edge  \
# 0  Jerry Adams is the patient being discussed and...
# 1  Jerry Adams is a 69 year old male, as stated i...
# 2  The patient has been diagnosed with prostate c...
# 3  According to the context, Jerry Adams is adher...
# 4  The patient denies experiencing symptoms of ch...
#
#                            chunk_id  count
# 0  38d3e5b0b5854945bd1ac139e7717c04      4
# 1  38d3e5b0b5854945bd1ac139e7717c04      4
# 2  38d3e5b0b5854945bd1ac139e7717c04      4
# 3  38d3e5b0b5854945bd1ac139e7717c04      4
# 4  38d3e5b0b5854945bd1ac139e7717c04      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                              node_1  \
# 2649  trying to walk on daily basis
# 2653                        vertigo
# 2654                        vertigo
# 2655                        vertigo
# 2657                        vertigo
#
#                                                  node_2  \
# 2649                reviewed and updated as appropriate
# 2653  class 3 severe obesity due to excess calories ...
# 2654                             essential hypertension
# 2655           malignant neoplasm of prostate (cms-hcc)
# 2657                               mixed hyperlipidemia
#
#                                                chunk_id  count  \
# 2649  38d3e5b0b5854945bd1ac139e7717c04,38d3e5b0b5854...      6
# 2653  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...      2
# 2654  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...      2
# 2655  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...      2
# 2657  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...      2
#
#                       edge
# 2649  contextual proximity
# 2653  contextual proximity
# 2654  contextual proximity
# 2655  contextual proximity
# 2657  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#       node_1                                             node_2  \
# 0    69 y.o.                                         controlled
# 1    69 y.o.                                     hyperlipidemia
# 2    69 y.o.                                       hypertension
# 3    69 y.o.                                        jerry adams
# 4    69 y.o.                                       patient id:
# ..       ...                                                ...
# 895  vertigo  class 3 severe obesity due to excess calories ...
# 896  vertigo                             essential hypertension
# 897  vertigo           malignant neoplasm of prostate (cms-hcc)
# 898  vertigo                               meclizine (antivert)
# 899  vertigo                               mixed hyperlipidemia
#
#                                               chunk_id  \
# 0    52e8e4a1ea834e36b9af0905031fdae3,94975eda0cac4...
# 1    38d3e5b0b5854945bd1ac139e7717c04,52e8e4a1ea834...
# 2    38d3e5b0b5854945bd1ac139e7717c04,52e8e4a1ea834...
# 3    38d3e5b0b5854945bd1ac139e7717c04,38d3e5b0b5854...
# 4    38d3e5b0b5854945bd1ac139e7717c04,94975eda0cac4...
# ..                                                 ...
# 895  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...
# 896  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...
# 897  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...
# 898                   6574280d6c5f42bab32af95103b63eb6
# 899  6574280d6c5f42bab32af95103b63eb6,6574280d6c5f4...
#
#                                                   edge  count
# 0                                 contextual proximity      3
# 1                                 contextual proximity      3
# 2                                 contextual proximity      3
# 3                                 contextual proximity     13
# 4                                 contextual proximity      2
# ..                                                 ...    ...
# 895                               contextual proximity      2
# 896                               contextual proximity      2
# 897                               contextual proximity      2
# 898  Causation relationship, as meclizine is prescr...      4
# 899                               contextual proximity      2
#
# [900 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (115,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  4
# [['69 y.o.', 'advised about diet', 'allergies', 'allergies, current medications, past family history, past medical history, past social history, past surgical history, problem list', 'appearance', 'atraumatic', 'chest pain', 'chronic medical problem', 'comfort eating', 'compliant with his medications', 'compliant with medications', 'conjunctiva/sclera', 'constitutional', 'controlled', 'current medications', 'eating more', 'follow up', 'good supportive system', 'has obesity', 'has vertigo', 'head', 'hyperlipidemia', 'hypertension', 'is a', 'is on radiation', 'is used for', 'jerry adams', 'light-headedness', 'negative', 'normal', 'normal appearance', 'obesity', 'past family history', 'past medical history', 'past social history', 'past surgical history', 'patient id:', 'patient id: ', 'prostate cancer', 'radiation', 'radiation therapy', 'recurrence', 'review and update', 'reviewed and updated as appropriate', 'rhinorrhea, sinus pain, sore throat', 'shortness of breath', 'started radiation therapy this week', 'statin', 'tolerating statin', 'trying to walk on daily basis'], ['abdomen', 'abdominal', 'bowel sounds', 'breath sounds', 'capillary refill', 'cardiovascular', 'cervical', 'cervical back', 'distension', 'effort', 'eyes', 'focal deficit', 'general', 'heart rate', 'heart rhythm', 'heart sounds', 'judgment', 'light', 'lungs', 'lymphadenopathy', 'musculoskeletal', 'neck', 'neurological', 'normal breath sounds', 'normal range of motion', 'normal range of time', 'patient care', 'psychiatric', 'pulmonary', 'pulmonary effort', 'pupils', 'range of motion', 'rate', 'return visit', 'rhythm', 'skin', 'thought content', 'thyroid'], ['alert', 'blood pressure under control', 'class 3 severe obesity due to excess calories with serious comorbidity and body mass index (bmi) of 40.0 to 44.9 in adult (cms-hcc)', 'cologuard (exact sciences)', 'colon cancer screening', 'dizziness', 'essential hypertension', 'health concern', 'individual seeking medical care', 'individual with medical history', 'jerry', 'malignant neoplasm of prostate (cms-hcc)', 'meclizine (antivert)', 'medical issue being addressed', 'medical term', 'mental status', 'mixed hyperlipidemia', 'orientation', 'patient', 'patient following with urologist', 'patient to continue simvastatin', 'spatial or temporal concept', 'symptom', 'time', 'vertigo'], ['immunization due', 'td (adult) with preservative']]

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                   node    color  group
# 0                                              69 y.o.  #57d3db      1
# 1                                   advised about diet  #57d3db      1
# 2                                            allergies  #57d3db      1
# 3    allergies, current medications, past family hi...  #57d3db      1
# 4                                           appearance  #57d3db      1
# ..                                                 ...      ...    ...
# 110                                            symptom  #91db57      3
# 111                                               time  #91db57      3
# 112                                            vertigo  #91db57      3
# 113                                   immunization due  #a157db      4
# 114                       td (adult) with preservative  #a157db      4
#
# [115 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "graphs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# graphs/index.html
